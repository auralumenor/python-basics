# %%
a=int(input("Enter a number: "))
if (a % 2 == 0) :
  print("Number is Even")
else :
  print("Number is Odd")
# Out:
# Enter a number: 102
# Number is Even

# %%
z=int(input("Enter The Year: "))
if (z % 4 == 0 or (z%100==0 and z%400==0) and z!=0 ) :
  print("Given Year is a Leap Year")
else :
  print("Given Year is not a Leap Year")
# Out:
# Enter The Year: 2024
# Given Year is a Leap Year

# %%
a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
c=int(input("Enter a number: "))
if (a>b and a>c) :
  print(a,"is the Greatest Number ")
if (c>b and c>a) :
  print(c,"is the Greatest Number ")
if (b>c and b>a) :
  print(b,"is the Greatest Number ")
# Out:
# Enter a number: 23
# Enter a number: 52
# Enter a number: 78
# 78 is the Greatest Number

# %%
z=(input("Enter a letter of the Alphabet: "))
if (z=='a','e','i','o','u') :
  print(z,"is a vowel")
else :
  print(z,"is a Consonant")
# Out:
# Enter a letter of the Alphabet: a
# a is a vowel

# %%
a=int(input("Enter a number: "))
fact = 1
if (a==0) :
  print("Factorial of 0 is not possible")
elif (a==1) :
  print("Factorial of 1 is 1")
elif (a<0) :
  print("Factorial of negative number is not possible")
else :
  for i in range (2,a+1):
    fact *= a
  print("The Factorial of the given number is ",fact)
# Out:
# Enter a number: 4
# The Factorial of the given number is  64
