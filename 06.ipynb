# %%
Java_Course={'Ritesh','Mayank','Avinash','Shivam','Rudra'}
Python_Course={'Subhash','Krish','Nihal','Manan'}
print(len(Java_Course))
print(len(Python_Course))
total=Java_Course|Python_Course
same=Java_Course&Python_Course
java=Java_Course-Python_Course
all=Java_Course^Python_Course
print('Total Students: ',len(total))
print('Students opted Both: ',len(same))
print("Students opted java: ",len(java))
print("Students opted any one course: ",len(all))
if len(total) > 4:

    total.discard("Rudra")

    total_students = {name for name in total if not name.startswith('M')}

    while len(total) > 4:
        total.pop()

    print("Final students set after removals:", total)
# Out:
# 5
# 4
# Total Students:  9
# Students opted Both:  0
# Students opted java:  5
# Students opted any one course:  9
# Final students set after removals: {'Nihal', 'Shivam', 'Avinash', 'Mayank'}
