# %%
student_details = {
    1: {"name": "Alice", "email_id": "alice@gmail.com", "phone_number": "1234567890", "marks": int(input("enter the marks for Alice: "))},
    2: {"name": "Ansh", "email_id": "ansh@gmail.com", "phone_number": "2345678901", "marks": int(input("enter the marks for Ansh: "))},
    3: {"name": "Ajay", "email_id": "ajay@gmail.com", "phone_number": "3456789012", "marks": int(input("enter the marks for Ajay: "))},
    4: {"name": "Arun", "email_id": "arun@gmail.com", "phone_number": "4567890123", "marks": int(input("enter the marks for Arun: "))},
    5: {"name": "Eva", "email_id": "eva@gmail.com", "phone_number": "5678901234", "marks": int(input("enter the marks for Eva: "))},
}
def calculate_average_and_topper(students):
    total_marks = 0
    total_students = len(students)
    topper = None
    highest_marks = 0

    for roll_no, details in students.items():
        total_marks += details["marks"]
        if details["marks"] > highest_marks:
            highest_marks = details["marks"]
            topper = details["name"]

    average_marks = total_marks / total_students if total_students > 0 else 0

    return average_marks, topper

average_marks, class_topper = calculate_average_and_topper(student_details)

print(f"Average Marks of each student: {average_marks:.2f}")
print(f"Class Topper: {class_topper}")
# Out:
# enter the marks for Alice: 56
# enter the marks for Ansh: 25
# enter the marks for Ajay: 85
# enter the marks for Arun: 45
# enter the marks for Eva: 55
# Average Marks of each student: 53.20
# Class Topper: Ajay
